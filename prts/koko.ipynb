# %%
import pandas as pd

df = pd.read_csv('./data/koko_imgs.csv')
df.head(5)
# Out:
#   name                                                url
# 0  阿米娅  https://andata.somedata.top/dataX/char/halfPic...
# 1   图耶  https://andata.somedata.top/dataX/char/halfPic...
# 2   空弦  https://andata.somedata.top/dataX/char/halfPic...
# 3  爱丽丝  https://andata.somedata.top/dataX/char/halfPic...
# 4   豆苗  https://andata.somedata.top/dataX/char/halfPic...

# %%
import pandas as pd

df = pd.read_csv('./prts_imgs_download.csv')
df.head(5)
# Out:
#            name                              url  \
# 0     寻访模拟/百种兵器     http://prts.wiki/w/寻访模拟/百种兵器
# 1     寻访模拟/冰封原野     http://prts.wiki/w/寻访模拟/冰封原野
# 2     寻访模拟/不羁逆流     http://prts.wiki/w/寻访模拟/不羁逆流
# 3  寻访模拟/不羁逆流 返场  http://prts.wiki/w/寻访模拟/不羁逆流 返场
# 4  寻访模拟/草垛上的风笛声  http://prts.wiki/w/寻访模拟/草垛上的风笛声
#
#                                                img
# 0    http://prts.wiki"/images/8/80/午间逸话活动预告03.jpg"
# 1  http://prts.wiki"/images/a/a3/活动预告-战地秘闻活动2.jpg"
# 2          http://prts.wiki"/images/c/c8/不羁逆流.jpg"
# 3       http://prts.wiki"/images/7/70/不羁逆流_返场.jpg"
# 4       http://prts.wiki"/images/2/23/草垛上的风笛声.jpg"

# %%
df['download'] = False
df.head(5)
# Out:
#   name                                                url  download
# 0  阿米娅  https://andata.somedata.top/dataX/char/halfPic...     False
# 1   图耶  https://andata.somedata.top/dataX/char/halfPic...     False
# 2   空弦  https://andata.somedata.top/dataX/char/halfPic...     False
# 3  爱丽丝  https://andata.somedata.top/dataX/char/halfPic...     False
# 4   豆苗  https://andata.somedata.top/dataX/char/halfPic...     False

# %%
import requests
import time
folder = './names/'  
header = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
}
for index, row in df.iterrows():
    if row['download'] == True:
        continue
#     print(row['stage'])
    try:
        map_url = row['url'] + '?x-oss-process=style/small-test'

        img_data = requests.get(map_url, headers = header).content
        img_name = row['name']

        with open(folder+img_name + '.webp', 'wb') as handler:
            handler.write(img_data)
        time.sleep(2)


        df.loc[df['name']==row['name'], ['download']] = True
    except Exception as e:
        print(e)
        pass

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install fake-useragent
# Out:
# Processing /Users/xiao2/Library/Caches/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031/fake_useragent-0.1.11-py3-none-any.whl
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-0.1.11
# WARNING: You are using pip version 20.2.3; however, version 20.3.3 is available.
# You should consider upgrading via the '/Users/xiao2/opt/anaconda3/envs/tf/bin/python -m pip install --upgrade pip' command.

# %%
import shutil
for index, row in df.iterrows():
    file_path = os.path.join('./extra_urls', row['stage'])
    if os.path.exists(file_path):
#         for root, dirs, files in os.walk(os.path.join(file_path, 'normal')):
#             for filename in files:
#                 if filename.endswith('.png') and not filename.startswith('.'):
#                     filepath = os.path.join(root, filename)
#                     dest_dir = file_path
#                     if not os.path.isdir(dest_dir):
#                         os.mkdir(dest_dir)
#                     shutil.move(filepath, os.path.join(dest_dir, filename))
        os.rmdir(os.path.join('./extra_urls', row['stage']))

# %%
import pandas as pd
df = pd.DataFrame(columns=['enemy_img_url', 'stages'])
df = pd.read_csv('./data/img_enemy_2.csv')

# wiki = pd.read_csv('./wiki_names.csv')

# df = df.join(wiki)
df.head(10)
# df.index
# Out:
#         stage                                      enemy_img_url
# 0      龙门_中转站  [{'头像 敌人 狂徒.png': 'http://prts.wiki/images/6/6...
# 1  切尔诺伯格_6区废墟  [{'头像 敌人 W.png': 'http://prts.wiki/images/7/76...
# 2  切尔诺伯格_破碎大道  [{'头像 敌人 高能源石虫.png': 'http://prts.wiki/images/...
# 3  切尔诺伯格_荒废工厂  [{'头像 敌人 寻仇者.png': 'http://prts.wiki/images/d/...
# 4   哥伦比亚_闭锁监狱  [{'头像 敌人 普通囚犯.png': 'http://prts.wiki/images/5...
# 5     荒野_风蚀高地  [{'头像 敌人 萨卡兹哨兵组长.png': 'http://prts.wiki/image...
# 6     荒野_黄铁峡谷  [{'头像 敌人 机动卫兵.png': 'http://prts.wiki/images/f...
# 7     龙门_军械库东  [{'头像 敌人 猎狗pro.png': 'http://prts.wiki/images/...
# 8     荒野_无序矿区  [{'头像 敌人 粉碎攻坚手.png': 'http://prts.wiki/images/...

# %%
df['download'] = False
df.head(5)
# Out:
#         stage                                      enemy_img_url  download
# 0      龙门_中转站  [{'头像 敌人 狂徒.png': 'http://prts.wiki/images/6/6...     False
# 1  切尔诺伯格_6区废墟  [{'头像 敌人 W.png': 'http://prts.wiki/images/7/76...     False
# 2  切尔诺伯格_破碎大道  [{'头像 敌人 高能源石虫.png': 'http://prts.wiki/images/...     False
# 3  切尔诺伯格_荒废工厂  [{'头像 敌人 寻仇者.png': 'http://prts.wiki/images/d/...     False
# 4   哥伦比亚_闭锁监狱  [{'头像 敌人 普通囚犯.png': 'http://prts.wiki/images/5...     False

# %%
# -*- coding:utf-8 -*-
import pandas as pd
df = pd.DataFrame(columns=['stage'])
# stages = ['1-11_遗忘', 'S2-1_迟缓-1', 'S2-2_迟缓-2', 'S2-3_封锁-1', 'S2-4_封锁-2', 'S2-5_术师-1', 'S2-6_术师-2', 'S2-7_术师-3', 'S2-8_陷阱-1', 'S2-9_陷阱-2', 'S2-10_窒息-1', 'S2-11_窒息-2', 'S2-12_窒息-3', 'S3-1_潜伏-1', 'S3-2_潜伏-2', 'S3-3_侦察-1', 'S3-4_侦察-2', 'S3-5_侦察-3', 'S3-6_集火-1', 'S3-7_隐匿-1', 'S4-1_晶簇-1', 'S4-2_晶簇-2', 'S4-3_晶簇-3', 'S4-4_多足-1', 'S4-5_多足-2', 'S4-6_多足-3', 'S4-7_狂怒-1', 'S4-8_狂怒-2', 'S4-9_狂怒-3', 'S4-10_坚守-1', 'S5-1_盘踞-1', 'S5-2_盘踞-2', 'S5-3_恶寒-1', 'S5-4_恶寒-2', 'S5-5_恐慌-1', 'S5-6_恐慌-2', 'S5-7_盘旋-1', 'S5-8_盘旋-2', 'S5-9_异状-1', 'H5-1_炼狱行动-1', 'H5-2_炼狱行动-2', 'H5-3_炼狱行动-3', 'H5-4_炼狱行动-4', 'S6-1_凝结-1', 'S6-2_凝结-2', '6-12_冰原之雪', 'S6-3_霜冻-1', 'S6-4_霜冻-2', 'H6-1_冰狱行动-1', 'H6-2_冰狱行动-2', 'H6-3_冰狱行动-3', 'H6-4_冰狱行动-4', 'S7-1_埋伏-1', 'S7-2_埋伏-2', 'H7-1_星火行动-1', 'H7-2_星火行动-2', 'H7-3_星火行动-3', 'H7-4_星火行动-4', 'M8-6_再见，只为再见', 'H8-1_狂夜行动-1', 'H8-2_狂夜行动-2', 'H8-3_狂夜行动-3', 'H8-4_狂夜行动-4', 'LS-1_遭遇战演习', 'LS-2_游击战演习', 'LS-3_阵地战演习', 'LS-4_特种战演习', 'LS-5_歼灭战演习', 'AP-1_源石开采保全', 'AP-2_源石运输保全', 'AP-3_精炼器材保全', 'AP-4_矿材仓库保全', 'AP-5_精炼工厂保全', 'CE-1_私人家具押运', 'CE-2_工业设备押运', 'CE-3_珍贵原料押运', 'CE-4_国际重犯押运', 'CE-5_机密情报押运', 'CA-1_疗养用地净空', 'CA-2_勘探基点净空', 'CA-3_巡逻路线净空', 'CA-4_任务区域净空', 'CA-5_战略要道净空', 'SK-1_废墟清剿', 'SK-2_窝点清剿', 'SK-3_哨所清剿', 'SK-4_据地清剿', 'SK-5_要塞清剿', 'PR-A-1_防守', 'PR-A-2_据守', 'PR-B-1_干涉', 'PR-B-2_打击', 'PR-C-1_急行', 'PR-C-2_冲锋', 'PR-D-1_突破', 'PR-D-2_猛攻', '乌萨斯_切尔诺伯格', '炎国_龙门外环', '炎国_龙门市区', '卡西米尔_大骑士领郊外', 'MB-1_密会', 'MB-2_另一个视角', 'MB-4_勇敢，莽撞', 'MB-5_危险交易', 'MB-6_制定计划', 'MB-7_背叛', 'MB-8_激战之末'];
stages = ['乌萨斯_北原冰封废城']
print(stages)
# stages.end()
# customers.loc[(customers['name']=='foo') & (customers['id']==1), ['balance']] =customers.balance.abs()
print(len(stages))
for each in stages:
    df = df.append({'stage': each}, ignore_index=True)
# for index, row in df.iterrows():

#     df.loc[df['download']==row['download'], ['enemy_img_url']] = stages[index]
        
df.head(5)
# Out:
# ['乌萨斯_北原冰封废城']
# 1
#         stage
# 0  乌萨斯_北原冰封废城

# %%
en = pd.read_csv('./data/enemy_wusasi.csv')
df = df.join(en)

# %%
df['download'] = False
df.head(5)
# Out:
#        stage                                         image_urls  \
# 0  BH-1_异常集聚  [{'道具 带框 奇景明信片.png': 'http://prts.wiki/images/...
# 1    BH-2_强风  [{'道具 带框 奇景明信片.png': 'http://prts.wiki/images/...
# 2  BH-3_致命失误  [{'道具 带框 奇景明信片.png': 'http://prts.wiki/images/...
# 3  BH-4_战术配合  [{'道具 带框 奇景明信片.png': 'http://prts.wiki/images/...
# 4    BH-5_齐唱  [{'道具 带框 奇景明信片.png': 'http://prts.wiki/images/...
#
#                                     extra_image_urls  \
# 0  [{'道具 带框 源岩.png': 'http://prts.wiki/images/e/e...
# 1  [{'道具 带框 源岩.png': 'http://prts.wiki/images/e/e...
# 2  [{'道具 带框 源岩.png': 'http://prts.wiki/images/e/e...
# 3  [{'道具 带框 源岩.png': 'http://prts.wiki/images/e/e...
# 4  [{'道具 带框 源岩.png': 'http://prts.wiki/images/e/e...
#
#                                              map_url  download
# 0  [{'BH-1 异常集聚 地图.png': 'http://prts.wiki/images...     False
# 1  [{'BH-2 强风 地图.png': 'http://prts.wiki/images/8...     False
# 2  [{'BH-3 致命失误 地图.png': 'http://prts.wiki/images...     False
# 3  [{'BH-4 战术配合 地图.png': 'http://prts.wiki/images...     False
# 4  [{'BH-5 齐唱 地图.png': 'http://prts.wiki/images/0...     False

# %%
stages = []
for index, row in df.iterrows():
    if row['stage'] == 'JT8-3_昂首，足践烈焰':
        stages.append(row['enemy_img_url'])

print(stages)
# Out:
# []

# %%
import requests
import json
import os
import time 
# from fake_useragent import UserAgent
# ua = UserAgent(cache=False)
header = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36',
}
specials = [
        "白马醇",
        "三水锰矿",
        "五水研磨石",
        "RMA70-24",
        "提纯源岩",
        "改量装置",
        "聚酸酯块",
        "糖聚块",
        "异铁块",
        "酮阵列",
        "聚合凝胶",
        "炽合金块",
        "晶体电路"
        ]
folder = 'enemy_img_url'
# folder = 'image_urls'

stages = ['龙门_中转站', '切尔诺伯格_6区废墟', '切尔诺伯格_破碎大道', '切尔诺伯格_荒废工厂', '哥伦比亚_闭锁监狱', '荒野_风蚀高地','荒野_黄铁峡谷','龙门_军械库东', '荒野_无序矿区']

for index, row in df.iterrows():
#     if index <= 86:
#         continue
    if row['download'] == True:
        continue
#     print(row['stage'])
    map_url = row[folder][1:-1].replace("\"","").replace("\'", "\"").split(",")
    for each in map_url:
        if each == '': continue
        for key, value in json.loads(each).items(): 
            print (key, value) 
            
            img_data = requests.get(value, headers = header).content
            if not os.path.exists(os.path.join(folder, row['stage'])):
                os.mkdir(os.path.join(folder, row['stage']))
#                 os.mkdir(os.path.join(folder, row['stage'], 'special'))
#                 os.mkdir(os.path.join(folder, row['stage'], 'normal'))
            img_name =  key.replace("头像 敌人 ","")
#             img_name = key

            with open(os.path.join(folder, row['stage'], img_name), 'wb') as handler:
                handler.write(img_data)
            time.sleep(2)
            

#             if img_name[:-4] in specials:
#                 with open(os.path.join(folder, row['stage'], 'special', img_name), 'wb') as handler:
#                     handler.write(img_data)
#                 time.sleep(2)
#             else:
#                 with open(os.path.join(folder, row['stage'], 'normal', img_name), 'wb') as handler:
#                     handler.write(img_data)  
#                 time.sleep(2.5)

    df.loc[df['stage']==row['stage'], ['download']] = True
    time.sleep(3)
# Out:
# 头像 敌人 狂徒.png http://prts.wiki/images/6/65/%E5%A4%B4%E5%83%8F_%E6%95%8C%E4%BA%BA_%E7%8B%82%E5%BE%92.png
# 头像 敌人 欺凌者.png http://prts.wiki/images/b/b8/%E5%A4%B4%E5%83%8F_%E6%95%8C%E4%BA%BA_%E6%AC%BA%E5%87%8C%E8%80%85.png
# 头像 敌人 打手.png http://prts.wiki/images/e/e5/%E5%A4%B4%E5%83%8F_%E6%95%8C%E4%BA%BA_%E6%89%93%E6%89%8B.png
# 头像 敌人 西西里人.png http://prts.wiki/images/4/4c/%E5%A4%B4%E5%83%8F_%E6%95%8C%E4%BA%BA_%E8%A5%BF%E8%A5%BF%E9%87%8C%E4%BA%BA.png
# 头像 敌人 射手.png http://prts.wiki/images/a/a5/%E5%A4%B4%E5%83%8F_%E6%95%8C%E4%BA%BA_%E5%B0%84%E6%89%8B.png
# 头像 敌人 猎狗pro.png http://prts.wiki/images/4/44/%E5%A4%B4%E5%83%8F_%E6%95%8C%E4%BA%BA_%E7